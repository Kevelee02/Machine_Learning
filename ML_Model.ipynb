# %%
#Primeiro importamos o dataset que queremos trabalhar, o primeiro modelo de ML, vai ser algo simples

# %%
import pandas as pd

melbourne_file_path = "https://raw.githubusercontent.com/dphi-official/First_ML_Model/master/melbourne_data.csv"
melbourne_data = pd.read_csv(melbourne_file_path) 
melbourne_data.columns
# Out:
# Index(['Unnamed: 0', 'Rooms', 'Bathroom', 'Landsize', 'Lattitude',
#        'Longtitude', 'Price'],
#       dtype='object')

# %%
#Definimos o nosso target ou alvo, que vai ser o preço
y = melbourne_data.Price

# %%
#Agora definimos nossas features, as variaveis que iremos usar para prever o nosso target
melbourne_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
x = melbourne_data[melbourne_features]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#Dando uma olhada na correlacao
sns.heatmap(melbourne_data[melbourne_features].corr(), annot=True)
plt.show()

# %%
#Agora iremos construir de fato o primeiro modelo

from sklearn.tree import DecisionTreeRegressor

# Definimos o modelo que iremos usar
melbourne_model = DecisionTreeRegressor(random_state=1)

# Definimos o dados
melbourne_model.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
#Por fim olhamos os preços previstos
print(x.head())
print("Os preços previstos são: ")
print(melbourne_model.predict(x.head()))

#Quantos mais features ou variaveis tivermos, melhor irá ser a previsão, mas esse foi um modelo simples de ML(meu primeiro)
# Out:
#    Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 0      2       1.0     156.0   -37.8079    144.9934
# 1      3       2.0     134.0   -37.8093    144.9944
# 2      4       1.0     120.0   -37.8072    144.9941
# 3      3       2.0     245.0   -37.8024    144.9993
# 4      2       1.0     256.0   -37.8060    144.9954
# Os preços previstos são:
# [1035000. 1465000. 1600000. 1876000. 1636000.]
